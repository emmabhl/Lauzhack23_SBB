# %%
from run_function import *
import api_requests as api

# %%
api.use_token()

# %%
data_user_ = {'origin': [6.629906, 46.518949], 'destination':[6.781826, 46.501346], 'departure_day':"2023-04-18", 'departure_time':"13:07",
             'transport_mean':{'TRAIN':True,'BUS':True, 'FOOT':True, 'CAR':True, 'SHIP':False, 
                               'TRAMWAY':False,'CABLEWAY':False, }}

run(data_user_)
# Out:
#              Journey_nbr        Departure                 Arrival  \
# Journey_nbr
# 5                      6         Lausanne               Palézieux
# 5                      6        Palézieux         Palézieux, gare
# 5                      6  Palézieux, gare        Puidoux, village
# 21                    22         Lausanne               Palézieux
# 21                    22        Palézieux         Palézieux, gare
# 21                    22  Palézieux, gare  Puidoux, Logis du Pont
# 22                    23         Lausanne                 Puidoux
# 22                    23          Puidoux           Puidoux, gare
# 22                    23    Puidoux, gare    Puidoux, En Botonnet
#
#                  Time_departure        Time_arrival  Journey_duration  \
# Journey_nbr
# 5           2023-04-18 15:44:00 2023-04-18 15:59:00                32
# 5           2023-04-18 15:59:00 2023-04-18 16:02:00                32
# 5           2023-04-18 16:03:00 2023-04-18 16:16:00                32
# 21          2023-04-18 15:44:00 2023-04-18 15:59:00                34
# 21          2023-04-18 15:59:00 2023-04-18 16:02:00                34
# 21          2023-04-18 16:03:00 2023-04-18 16:18:00                34
# 22          2023-04-18 14:13:00 2023-04-18 14:22:00                30
# 22          2023-04-18 14:22:00 2023-04-18 14:24:00                30
# 22          2023-04-18 14:37:00 2023-04-18 14:43:00                30
#
#              Tot_nbr_stages Transport_mode
# Journey_nbr
# 5                         3          TRAIN
# 5                         3           FOOT
# 5                         3            BUS
# 21                        3          TRAIN
# 21                        3           FOOT
# 21                        3            BUS
# 22                        3          TRAIN
# 22                        3           FOOT
# 22                        3            BUS
